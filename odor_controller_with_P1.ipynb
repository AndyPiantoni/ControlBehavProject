# %% [markdown]
# # Olfaction Controller
#
# I am using here a big part of the code seen in week3 of the exercises. First create an odor arena with one attractive odor source only.
# ## Odor source

# %%
import numpy as np

# random state seed for reproducibility
seed = 1

# Odor source: array of shape (num_odor_sources, 3) - xyz coords of odor sources
odor_source = np.array([[24, 10, 1.5]])

# Peak intensities: array of shape (num_odor_sources, odor_dimensions)
# For each odor source, if the intensity is (x, 0) then the odor is in the 1st dimension
# (in this case attractive). If it's (0, x) then it's in the 2nd dimension (in this case
# aversive)
peak_odor_intensity = np.array([[1, 0]])

# Marker colors: array of shape (num_odor_sources, 4) - RGBA values for each marker,
# normalized to [0, 1]
marker_colors = [[255, 127, 14]]
marker_colors = np.array([[*np.array(color) / 255, 1] for color in marker_colors])

odor_dimensions = len(peak_odor_intensity[0])

# Gains for the two odors (negative = attractive, positive = aversive)
odor_gains = np.array([-500, 80])

# %% [markdown]
# ## OdorArena

# %%
from flygym.arena import OdorArena
from movodor_arena import MovOdorArena

arena = MovOdorArena(
    size=(300, 300),
    friction=(1, 0.005, 0.0001),
    num_sensors=4,
    move_speed=0,
    move_direction="right",
    odor_source=odor_source,
    peak_intensity=peak_odor_intensity,
    diffuse_func=lambda x: x**-2,
    marker_colors=marker_colors,
    marker_size=0.3,
)

# %% [markdown]
# ## New Camera
# Camera which follows the fly from birdeye perspective

# %%
from dm_control.mjcf.physics import Physics
from flygym import Camera


class BirdEyeAnimatCamera(Camera):
    def __init__(self, fly, z_position, **kwargs):
        super().__init__(fly, **kwargs)
        self._fly = fly
        self._z_position = z_position
    
    def _update_cam_pos(self, physics: Physics, floor_height: float):
        cam = physics.bind(self._cam)
        cam_pos = cam.xpos.copy()
        cam_pos[2] = self.cam_offset[2] + floor_height + self._z_position
        cam.xpos = cam_pos

# %% [markdown]
# ### Place the fly
# We use `HybridTurningNMF`Controller for turning of the fly.

# %%
from pathlib import Path
import matplotlib.pyplot as plt
from flygym import Parameters, Camera, SingleFlySimulation 
from hybrid_turning_fly import HybridTurningFly
from odor_turning_fly import OdorTaxisFly

Path("./outputs").mkdir(exist_ok=True)



timestep = 1e-4
decision_interval = 0.05
run_time = 5



fly_male = OdorTaxisFly(
    name="male",
    odor_threshold = 0.5,
    odor_dimensions=odor_dimensions,
    odor_gains=odor_gains,
    timestep=timestep,
    enable_adhesion=True,
    enable_olfaction=True,
    spawn_pos=(0, 0, 0.2),
)

cam = Camera(
    fly=fly_male,
    camera_id="birdeye_cam",
    window_size=(800, 608),
    play_speed=0.5,
)

sim = SingleFlySimulation(
    fly=fly_male,
    cameras=[cam],
    arena=arena,
    timestep=timestep,
)
   
for i in range(1):
    sim.step(np.zeros(2))
    sim.render()
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.imshow(cam._frames[-1])
ax.axis("off")
fig.savefig("./outputs/olfaction_env.png")

# %% [markdown]
# ## Controller for odor taxis
#
# Let's design a simple hand-tuned controller for odor-guided taxis. We start by calculating the left-right asymmetry of the odor intensity $I$ for each odor $o$:
#
# $$
# \Delta I_o = \frac{I_\text{left,o} - I_\text{right,o}}{(I_\text{left,o} + I_\text{right,o}) / 2}
# $$
#
# Then, we multiply $\Delta I_o$ by a gain $\gamma_o$ for each odor dimension and take the sum $s$. Attractive and aversive odors will have different signs in their gains.
#
# $$
# s = \sum_{o} \gamma_o \Delta I_o
# $$
#
# We transform $s$ nonlinearly to avoid overly drastic turns when the asymmetry is subtle and to crop it within the range [0, 1). This gives us a turning bias $b$:
#
# $$
# b = \tanh(s^2)
# $$
#
# Then, we modulate the descending signal $\delta$ based on $b$ and the sign of $s$:
#
# $$
# \delta_\text{left} =
#     \begin{cases}
#     \delta_\text{max} & \text{if } s>0\\
#     \delta_\text{max} - b(\delta_\text{max} - \delta_\text{min})  & \text{otherwise}
#     \end{cases}
#     \qquad
#     \delta_\text{right} =
#     \begin{cases}
#     \delta_\text{max} - b(\delta_\text{max} - \delta_\text{min}) & \text{if } s>0\\
#     \delta_\text{max}  & \text{otherwise}
#     \end{cases}
# $$
#
# where, $\delta_\text{min}$, $\delta_\text{max}$ define the range of the descending signal. Here, we will use the following parameters:
#
# - $\gamma_\text{attractive} = -500$ (negative ipsilateral gain leads to positive taxis)
# - $\gamma_\text{aversive} = 80$ (positive ipsilateral gain leads to negative taxis)
# - $\delta_\text{min} = 0.2$
# - $\delta_\text{max} = 1$
#
# Finally we set the descending signal $\delta$ to zero if the intensity of the attractive odor is above a threshold (i.e. the fly reached a certain distance to the odor source).
#
# $$
# \delta_\text{left} =
#     \begin{cases}
#     0 & \text{if } I_{attractive}>\text{threshold}\\
#     \delta_\text{left} & \text{otherwise}
#     \end{cases}
#     \qquad
#     \delta_\text{right} =
#     \begin{cases}
#     0 & \text{if } I_{attractive}>\text{threshold}\\
#     \delta_\text{right}  & \text{otherwise}
#     \end{cases}
# $$
#
# As before, we will recalculate the steering signal every 0.05 seconds. Let's implement this in Python:

# %%
def p1_control_signal(run_time: float, time_step: float) -> np.ndarray:
    """Returns a P1 signal [0,1].
    The control signal is a 2D array of shape (num_time_steps, 2)"""
    
    # P1 signal is a 2D array of shape (num_time_steps, 2)
    p1_signal = np.ones((int(run_time / time_step), 1))
    
    # Create a sine wave signal 
    p1_signal[:, 0] = 0.5*(np.sin(2 * np.pi * np.linspace(0, run_time, int(run_time / time_step)))+1)
    
    
    return p1_signal

def plot_p1_signal(p1_signal):
    fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
    ax.plot(p1_signal)
    ax.set_xlabel("Time steps")
    ax.set_ylabel("P1 signal")
    ax.set_title("P1 signal")

# %%
num_decision_steps = int(run_time / decision_interval)
physics_steps_per_decision_step = int(decision_interval / timestep)
p1_signal = p1_control_signal(run_time, decision_interval)
plot_p1_signal(p1_signal)

# %%
from tqdm import trange

num_decision_steps = int(run_time / decision_interval)
physics_steps_per_decision_step = int(decision_interval / timestep)

obs_hist = []
odor_history = []
obs, _ = sim.reset()
reached_odor_source = False
assert num_decision_steps == len(p1_signal), "Number of decision steps must match the length of the P1 signal"
for i in trange(num_decision_steps):
    
    control_signal = fly_male.process_odor_intensities(obs["odor_intensity"])
    
    # modulate control signal with P1 signal
    control_signal = control_signal * p1_signal[i]        

    for j in range(physics_steps_per_decision_step):
        obs, _, _, _, _ = sim.step(control_signal)
        rendered_img = sim.render()
        if rendered_img is not None:
            # record odor intensity too for video
            odor_history.append(obs["odor_intensity"])
        obs_hist.append(obs)
# Out:
#  43%|████▎     | 43/100 [04:36<06:05,  6.42s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 19
#      16 control_signal = control_signal * p1_signal[i]
#      18 for j in range(physics_steps_per_decision_step):
# ---> 19     obs, _, _, _, _ = sim.step(control_signal)
#      20     rendered_img = sim.render()
#      21     if rendered_img is not None:
#      22         # record odor intensity too for video
#
# File c:\users\lisas\documents\epfl\ma1\bioeng-456_controlling-behaviour-in-animals-and-robots\flygym-v1\flygym\simulation.py:465, in SingleFlySimulation.step(self, action)
#     436 """Step the simulation environment.
#     437
#     438 Parameters
#    (...)
#     462     additional information.
#     463 """
#     464 key = self.flies[0].name
# --> 465 obs, reward, terminated, truncated, info = super().step({key: action})
#     466 return obs[key], reward, terminated, truncated, info[key]
#
# File c:\users\lisas\documents\epfl\ma1\bioeng-456_controlling-behaviour-in-animals-and-robots\flygym-v1\flygym\simulation.py:222, in Simulation.step(self, action)
#     220 for fly in self.flies:
#     221     key = fly.name
# --> 222     obs_, reward_, terminated_, truncated_, info_ = fly.post_step(self)
#     223     obs[key] = obs_
#     224     reward[key] = reward_
#
# File c:\users\lisas\documents\epfl\ma1\bioeng-456_controlling-behaviour-in-animals-and-robots\flygym-v1\flygym\fly.py:1278, in Fly.post_step(self, sim)
#    1277 def post_step(self, sim: "Simulation"):
# -> 1278     obs = self.get_observation(sim)
#    1279     reward = self.get_reward()
#    1280     terminated = self.is_terminated()
#
# File c:\users\lisas\documents\epfl\ma1\bioeng-456_controlling-behaviour-in-animals-and-robots\flygym-v1\flygym\fly.py:1169, in Fly.get_observation(self, sim)
#    1167 # vision
#    1168 if self.enable_vision:
# -> 1169     self._update_vision(sim)
#    1170     obs["vision"] = self._curr_visual_input.astype(np.float32)
#    1172 return obs
#
# File c:\users\lisas\documents\epfl\ma1\bioeng-456_controlling-behaviour-in-animals-and-robots\flygym-v1\flygym\fly.py:1016, in Fly._update_vision(self, sim)
#    1013 sim.arena.pre_visual_render_hook(physics)
#    1015 for side in ["L", "R"]:
# -> 1016     raw_img = physics.render(
#    1017         width=vision_config["raw_img_width_px"],
#    1018         height=vision_config["raw_img_height_px"],
#    1019         camera_id=f"{self.name}/{side}Eye_cam",
#    1020     )
#    1021     fish_img = np.ascontiguousarray(self.retina.correct_fisheye(raw_img))
#    1022     readouts_per_eye = self.retina.raw_image_to_hex_pxls(fish_img)
#
# File c:\Users\lisas\miniconda3\envs\flygym-v1\Lib\site-packages\dm_control\mujoco\engine.py:229, in Physics.render(self, height, width, camera_id, overlays, depth, segmentation, scene_option, render_flag_overrides, scene_callback)
#     191 """Returns a camera view as a NumPy array of pixel values.
#     192
#     193 Args:
#    (...)
#     221   The rendered RGB, depth or segmentation image.
#     222 """
#     223 camera = Camera(
#     224     physics=self,
#     225     height=height,
#     226     width=width,
#     227     camera_id=camera_id,
#     228     scene_callback=scene_callback)
# --> 229 image = camera.render(
#     230     overlays=overlays, depth=depth, segmentation=segmentation,
#     231     scene_option=scene_option, render_flag_overrides=render_flag_overrides)
#     232 camera._scene.free()  # pylint: disable=protected-access
#     233 return image
#
# File c:\Users\lisas\miniconda3\envs\flygym-v1\Lib\site-packages\dm_control\mujoco\engine.py:891, in Camera.render(self, overlays, depth, segmentation, scene_option, render_flag_overrides)
#     889 with self.scene.override_flags(render_flag_overrides):
#     890   with self._physics.contexts.gl.make_current() as ctx:
# --> 891     ctx.call(self._render_on_gl_thread, depth=depth, overlays=overlays)
#     893 if depth:
#     894   # Get the distances to the near and far clipping planes.
#     895   extent = self._physics.model.stat.extent
#
# File c:\Users\lisas\miniconda3\envs\flygym-v1\Lib\site-packages\dm_control\_render\executor\render_executor.py:138, in PassthroughRenderExecutor.call(self, func, *args, **kwargs)
#     136 def call(self, func, *args, **kwargs):
#     137   self._check_locked()
# --> 138   return func(*args, **kwargs)
#
# File c:\Users\lisas\miniconda3\envs\flygym-v1\Lib\site-packages\dm_control\mujoco\engine.py:804, in Camera._render_on_gl_thread(self, depth, overlays)
#     801 """Performs only those rendering calls that require an OpenGL context."""
#     803 # Render the scene.
# --> 804 mujoco.mjr_render(self._rect, self._scene.ptr,
#     805                   self._physics.contexts.mujoco.ptr)
#     807 if not depth:
#     808   # If rendering RGB, draw any text overlays on top of the image.
#     809   for overlay in overlays:
#
# KeyboardInterrupt:

# %%
fly_pos_hist = np.array([obs["fly"][0, :2] for obs in obs_hist])
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.scatter(
    [odor_source[0, 0]],
    [odor_source[0, 1]],
    marker="o",
    color="tab:orange",
    s=50,
    label="Attractive",
)
# ax.scatter([odor_source[2, 0]], [odor_source[2, 1]], marker="o", color="tab:blue", s=50)
ax.plot(fly_pos_hist[:, 0], fly_pos_hist[:, 1], color="k", label="Fly trajectory")
ax.set_aspect("equal")
ax.set_xlim(-1, 25)
ax.set_ylim(-5, 15)
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.legend(ncols=3, loc="lower center", bbox_to_anchor=(0.5, -0.6))
fig.savefig("./outputs/odor_taxis_trajectory.png")

# %%
#plot histroy of observations odors intensities
odor_history = [np.average(obs_hist[i]["odor_intensity"].reshape((odor_dimensions, 2, 2)), axis=1) for i in range(len(obs_hist))]
odor_l_history = [odor_history[i][:, 0] for i in range(len(odor_history))]
odor_r_history = [odor_history[i][:, 1] for i in range(len(odor_history))]

plot_odor_l = np.array(odor_l_history)
plot_odor_r = np.array(odor_r_history)
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.plot(plot_odor_l, label=["Left attractive odor intensity", "Left aversive odor intensity"])
ax.plot(plot_odor_r, label=["Right attractive odor intensity", "Right aversive odor intensity"])
ax.set_xlabel("Time step")
ax.set_ylabel("Odor intensity")
ax.legend()
plt.show()

# %%
cam.save_video("./outputs/olfaction_p1_controller.mp4")

# %%
from IPython.display import Video

Video("./outputs/olfaction_p1_controller.mp4", width=800, height=608)
# Out:
# <video src="./outputs/olfaction_test1.mp4" controls  width="800"  height="608">
#       Your browser does not support the <code>video</code> element.
#     </video>
